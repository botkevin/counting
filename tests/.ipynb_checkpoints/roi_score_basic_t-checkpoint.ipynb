# %%
import sys
sys.path.append("../")
import detect_organized as det
import roi
import display
import score

import cv2
import imutils
import skimage
from matplotlib import pyplot as plt
from skimage.color import rgb2gray

# %%
import numpy as np

# %%
img1 = skimage.io.imread("../images/screen.jpg")
img1 = imutils.resize(img1, width=500)

img2 = skimage.io.imread("../images/find_the_screen.jpg")
img2 = imutils.resize(img2, width=500)

# %%
master_img = img1
search_img = img2

# %%
boxes = roi.s_search(img2)
# Out:
# s_search start
# s_search end

# %%
# img1 = skimage.io.imread("../images/screen.jpg")
img1 = cv2.imread('../images/screen.jpg',0)
img1 = imutils.resize(img1, width=500)

# img2 = skimage.io.imread("../images/find_the_screen.jpg")
img2 = cv2.imread('../images/find_the_screen.jpg',0)
img2 = imutils.resize(img2, width=500)

# %%
# plt.imshow(img1)
# print(img1.shape)
# plt.show()
# plt.imshow(img2)
# plt.show()

# %%
rois = roi.check_roi_good(img1,img2,boxes,"surf")
# Out:
# 6
# 14
# 16
# 59
# 68
# 86
# 87
# 92
# 96
# 97
# 103
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 128
# 129
# 132
# 133
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 165
# 166
# 167
# 168
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 207
# 208
# 209
# 210
# 212
# 215
# 216
# 217
# 218
# 221
# 224
# 225
# 226
# 227
# 230
# 232
# 235
# 240
# 242
# 244
# 245
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 257
# 258
# 261
# 262
# 263
# 265
# 266
# 269
# 270
# 274
# 277
# 278
# 286
# 288
# 292
# 295
# 299
# 301
# 305
# 306
# 309
# 312
# 313
# 314
# 316
# 317
# 319
# 321
# 322
# 323
# 324

# %%
len(boxes)
# Out:
# 325

# %%
len(rois)
# Out:
# 169

# %%
display.just_boxes([x[0] for x in rois],search_img)

# %%
idxs = score.basic_cutoff(rois, 200)

# %%
len(idxs)
# Out:
# 20

# %%
cutoff_boxes = [rois[i][0] for i in idxs]

# %%
display.just_boxes(cutoff_boxes,search_img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-f208d3b389fc> in <module>
# ----> 1 display.just_boxes(cutoff_boxes,search_img)
#
# ~/Documents/counting/display.py in just_boxes(boxes, img)
#      51 def just_boxes(boxes, img):
#      52     for box in boxes:
# ---> 53         start_point = box[:2]
#      54         end_point = box[2:]
#      55         color = (255, 0, 0)
#
# IndexError: invalid index to scalar variable.

# %% [markdown]
# # testing

# %%
# method = "surf"
# kp1, des1 = det.detect(dec, img1)
# print (img2.shape)
# rect = (0, 100, 100, 200)
# mask = roi._make_mask(img2.shape, rect)
# plt.imshow(mask),plt.show()
# kp2, des2 = det.detect(dec, img2, mask)
# print(len(kp1) ,"|", len(kp2))
# matches = det.match(des1, des2, "FLANN", method)
# good = det.ratio(matches)

# display.show(kp1, kp2, img1, img2, good, flag = 0)

# %%
# method = "surf"
# dec = det.detector(method)
# kp1, des1 = det.detect(dec, img1)
# kp2, des2 = det.detect(dec, img2)

# matches = det.match(des1, des2, "FLANN", method)
# good = det.ratio(matches)

# display.show(kp1, kp2, img1, img2, good, flag = 0)
# display.show(kp1, kp2, img1, img2, good, flag = 1)
# display.show(kp1, kp2, img1, img2, good, flag = 2)
